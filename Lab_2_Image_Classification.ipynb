# %% [markdown]
# # Image Classification using Yolov10
#
# YOLOv10: Real-Time End-to-End Object Detection. YOLOv10 achieves state-of-the-art performance with significantly reduced computational overhead.
#
# ## 🛠️ Supported Hardware
#
# This notebook can run in a CPU or in a GPU.
#
# ✅ AMD Instinct™ Accelerators
# ✅ AMD Radeon™ RX/PRO Graphics Cards
# ✅ AMD EPYC™ Processors
# ✅ AMD Ryzen™ (AI) Processors
#
# Suggested hardware: **AI PC powered by AMD Ryzen™ AI Processors**
#
# :::
# ::::
#
# ## 🎯 Goals
#
# - Show you how to download several models from HuggingFace
# - Run Yolov10 on an AMD platform
# - Run inference with Yolov10 on an image
# - Compare Yolov10 different model sizes
#
# :::{seealso}
# - Image classification using [Yolov10](https://huggingface.co/jameslahm/yolov10m)
# - [YOLOv10: Real-Time End-to-End Object Detection Paper](https://arxiv.org/abs/2405.14458)
# - [YOLOv10: Real-Time End-to-End Object Detection GitHub](https://github.com/THU-MIG/yolov10)
# - [YOLOv10: Real-Time End-to-End Object Detection Docs](https://docs.ultralytics.com/models/yolov10/)
# :::

# %% [markdown]
# Install the required libraries

# %%
# !pip install ultralytics git+https://github.com/THU-MIG/yolov10.git
# Out:
# Collecting git+https://github.com/THU-MIG/yolov10.git
#   Cloning https://github.com/THU-MIG/yolov10.git to /tmp/pip-req-build-9lw044ok
#   Running command git clone --filter=blob:none --quiet https://github.com/THU-MIG/yolov10.git /tmp/pip-req-build-9lw044ok
#   Resolved https://github.com/THU-MIG/yolov10.git to commit 453c6e38a51e9d1d5a2aa5fb7f1014a711913397
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ultralytics
#   Downloading ultralytics-8.4.157-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (3.9.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (2.8.0+rocm7.2.0.lw.gitbf943426)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (0.23.0+rocm7.2.0.git824e8c87)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (4.67.1)
# Requirement already satisfied: psutil in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (7.2.2)
# Collecting py-cpuinfo (from ultralytics==8.1.34)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting thop>=0.1.1 (from ultralytics==8.1.34)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/venv/lib/python3.12/site-packages (from ultralytics==8.1.34) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.1.34) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2026.2.25)
# Requirement already satisfied: filelock in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (4.15.0)
# Requirement already satisfied: setuptools in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (80.10.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (1.14.0)
# Requirement already satisfied: networkx in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.1.6)
# Requirement already satisfied: fsspec in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2026.1.0)
# Requirement already satisfied: triton==3.4.0+rocm7.2.0.git0cace8d2 in /opt/venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.4.0+rocm7.2.0.git0cace8d2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.1.34) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.34) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: ultralytics
#   Building wheel for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=732491 sha256=ee8814a60f9842167b3bd8e13c87e04dc4f689d6204f7bd9b5b88641e171dbff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hcfpi5z5/wheels/35/9a/d9/ec58d6096ceff21c4a77b18cd266af11385b347ca19a307597
# Successfully built ultralytics
# Installing collected packages: py-cpuinfo, thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ultralytics] [ultralytics]
# Successfully installed py-cpuinfo-9.0.0 thop-0.1.1.post2209072238 ultralytics-8.1.34
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 🚀 Run Yolov10 on an AMD Platform
#
# Import packages, in particular [Hugging Face `transformers`](https://huggingface.co/docs/transformers/en/index) that helps downloading the model from the Hugging Face repository.

# %%
from ultralytics import YOLOv10
from PIL import Image
import torch
from IPython.display import display

# %% [markdown]
# Get the yolov10 (medium) pre-trained model using the `YOLOv10` API

# %%
model = YOLOv10.from_pretrained('jameslahm/yolov10m')

# %% [markdown]
# ```{note}
# You can print the the model to see the different layers.
# ```
# ```python
# print(model)
# ```

# %% [markdown]
# If a GPU is available, move the model to the GPU

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(f'{device=}')
# Out:
# device=device(type='cuda')

# %% [markdown]
# Let's run inference using a sample image and then display the result.

# %%
test_img = '000000039769.jpg'
result = model.predict(source=f'http://images.cocodataset.org/val2017/{test_img}', save=True)
image = Image.open(f'{result[0].save_dir}/{test_img}')
display(image)
# Out:
# Downloading http://images.cocodataset.org/val2017/000000039769.jpg to '000000039769.jpg'...
# 100%|██████████| 169k/169k [00:00<00:00, 678kB/s]
# image 1/1 /notebooks/FINAL/000000039769.jpg: 480x640 2 cats, 1 couch, 2 remotes, 4335.0ms
# Speed: 3.0ms preprocess, 4335.0ms inference, 1442.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %% [markdown]
# Let's run multiple inferences inside of a loop

# %%
images = ['000000039769.jpg', '000000002157.jpg', '000000032610.jpg', '000000037777.jpg', '000000057597.jpg', '000000087470.jpg', '000000098520.jpg']
for test_img in images:
    result = model.predict(source=f'http://images.cocodataset.org/val2017/{test_img}', save=True)
    image = Image.open(f'{result[0].save_dir}/{test_img}')
    display(image)
# Out:
# Found http://images.cocodataset.org/val2017/000000039769.jpg locally at 000000039769.jpg
# image 1/1 /notebooks/FINAL/000000039769.jpg: 480x640 2 cats, 1 couch, 2 remotes, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>
# Downloading http://images.cocodataset.org/val2017/000000002157.jpg to '000000002157.jpg'...
# 100%|██████████| 122k/122k [00:00<00:00, 481kB/s]
# image 1/1 /notebooks/FINAL/000000002157.jpg: 448x640 11 wine glasss, 2 cups, 2 knifes, 1 cake, 1 dining table, 4090.4ms
# Speed: 1.1ms preprocess, 4090.4ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>
# Downloading http://images.cocodataset.org/val2017/000000032610.jpg to '000000032610.jpg'...
# 100%|██████████| 146k/146k [00:00<00:00, 577kB/s]
# image 1/1 /notebooks/FINAL/000000032610.jpg: 448x640 1 backpack, 1 tv, 3 laptops, 1 keyboard, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>
# Downloading http://images.cocodataset.org/val2017/000000037777.jpg to '000000037777.jpg'...
# 100%|██████████| 39.9k/39.9k [00:00<00:00, 492kB/s]
# image 1/1 /notebooks/FINAL/000000037777.jpg: 448x640 1 banana, 5 oranges, 2 chairs, 1 dining table, 1 oven, 1 refrigerator, 35.3ms
# Speed: 5.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x230>
# Downloading http://images.cocodataset.org/val2017/000000057597.jpg to '000000057597.jpg'...
# 100%|██████████| 193k/193k [00:00<00:00, 572kB/s]
# image 1/1 /notebooks/FINAL/000000057597.jpg: 448x640 6 persons, 1 car, 1 sports ball, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426>
# Downloading http://images.cocodataset.org/val2017/000000087470.jpg to '000000087470.jpg'...
# 100%|██████████| 238k/238k [00:00<00:00, 703kB/s]
# image 1/1 /notebooks/FINAL/000000087470.jpg: 480x640 3 persons, 13 cows, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x470>
# Downloading http://images.cocodataset.org/val2017/000000098520.jpg to '000000098520.jpg'...
# 100%|██████████| 118k/118k [00:00<00:00, 469kB/s]
# image 1/1 /notebooks/FINAL/000000098520.jpg: 480x640 1 airplane, 2 trucks, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %% [markdown]
# There are a number of `Yolov10` models available, each with a different number of parameters. Running the cell below you will download 6 different `Yolov10` models and observe the number of parameters and the size of each model.

# %%
models = ['yolov10n', 'yolov10s', 'yolov10m', 'yolov10b', 'yolov10l', 'yolov10x']

def model_size(model):
    param_size = 0
    for param in model.parameters():
        param_size += param.nelement() * param.element_size()
    buffer_size = 0
    for buffer in model.buffers():
        buffer_size += buffer.nelement() * buffer.element_size()
    return param_size + buffer_size

for m in models:
    model = YOLOv10.from_pretrained(f'jameslahm/{m}')
    size_all_mb =  (model_size(model)) / 1024**2
    total_params = sum(p.numel() for p in model.parameters())
    print(f'Model: {m} with {total_params:10,} parameters, size: {size_all_mb:7.3f}MB')
# Out:
# Model: yolov10n with  2,775,520 parameters, size:  10.667MB
# Model: yolov10s with  8,128,272 parameters, size:  31.169MB
# Model: yolov10m with 16,576,768 parameters, size:  63.494MB
# Model: yolov10b with 20,574,384 parameters, size:  78.790MB
# Model: yolov10l with 25,888,688 parameters, size:  99.132MB
# Model: yolov10x with 31,808,960 parameters, size: 121.883MB

# %% [markdown]
# ```{tip}
# Exercise for the reader, replace the `yolov10m` model (second cell of this notebook) with any other `Yolov10` model available and re run the notebook. Do you notice any difference in the accuracy of the classification?
# ```

# %% [markdown]
# ----------
# Copyright (C) 2026 Advanced Micro Devices, Inc. All rights reserved.
#
# SPDX-License-Identifier: MIT
